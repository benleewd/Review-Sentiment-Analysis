# %%
import os
import glob
import pickle
import time
#import pyperclip
import fnmatch
import datetime
from datetime import date, timedelta
import pandas as pd
import numpy as np
from string import punctuation, ascii_lowercase
import regex as re
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from time import sleep

# %%
from tqdm._tqdm_notebook import tqdm_notebook
tqdm_notebook.pandas()
import nltk
nltk.download('punkt')
# Out:
# <ipython-input-2-e339116fd790>:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   from tqdm._tqdm_notebook import tqdm_notebook
# C:\Anaconda3\lib\site-packages\tqdm\std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Wyatt\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score

# %%
df_sample = pd.read_csv('df_clustering_final.csv', index_col=None, header=0, delimiter = ',',encoding='utf-8-sig')

# %%
df_sample
# Out:
#         review_id                                             review  rating  \
# 0               0  Ga disappointed neat products .. Meletot Hilsn...       1
# 1               1    Rdtanya replace broken glass, broken chargernya       1
# 2               2  Nyesel bngt dsni shopping antecedent photo mes...       1
# 3               3      Sent a light blue suit goods ga want a refund       1
# 4               4  Pendants came with dents and scratches on its ...       1
# ...           ...                                                ...     ...
# 209724     209673                                      Super super,,       5
# 209725     209681                                  Excellent quality       5
# 209726     209696  nice nice nice nice nice nice nice nice nice n...       5
# 209727     209701                        Bismillahirrahmanirrahim 🙏🙏       5
# 209728     209717                                       Nice product       5
#
#         review_length  word_count  \
# 0                  78          12
# 1                  47           6
# 2                 323          50
# 3                  45          10
# 4                 109          18
# ...               ...         ...
# 209724             13           2
# 209725             17           2
# 209726            249          50
# 209727             27           2
# 209728             12           2
#
#                                              text_en_only  \
# 0       disappointed neat products meletot hilsnyaa sp...
# 1          rdtanya replace broken glass broken chargernya
# 2       nyesel bngt dsni shopping antecedent photo mes...
# 3                  sent light blue suit goods want refund
# 4       pendants came with dents and scratches its sur...
# ...                                                   ...
# 209724                                        super super
# 209725                                  excellent quality
# 209726  nice nice nice nice nice nice nice nice nice n...
# 209727                                                NaN
# 209728                                       nice product
#
#                                  text_en_only_rm_stopping  \
# 0       disappointed neat products meletot hilsnyaa sp...
# 1          rdtanya replace broken glass broken chargernya
# 2       nyesel bngt dsni shopping antecedent photo mes...
# 3                  sent light blue suit goods want refund
# 4       pendants came dents scratches surface coating ...
# ...                                                   ...
# 209724                                        super super
# 209725                                  excellent quality
# 209726  nice nice nice nice nice nice nice nice nice n...
# 209727                                                NaN
# 209728                                       nice product
#
#                                        text_en_only_lemma  \
# 0       hilsnyaa disappointed meletot delivery good sp...
# 1                 replace rdtanya glass chargernya broken
# 2       nyesel face super bngt open pdahal according p...
# 3                   light refund good sent suit blue want
# 4       dent coating came colour like quickly scratch ...
# ...                                                   ...
# 209724                                              super
# 209725                                  excellent quality
# 209726                                               nice
# 209727                                                NaN
# 209728                                       product nice
#
#         review_length_processed  word_count_processed  cluster_pred
# 0                            62                     8           109
# 1                            39                     5           228
# 2                           205                    29           295
# 3                            37                     7            29
# 4                            73                    11            96
# ...                         ...                   ...           ...
# 209724                        5                     1            -1
# 209725                       17                     2            -1
# 209726                        4                     1            -1
# 209727                        0                     0            -1
# 209728                       12                     2            -1
#
# [209729 rows x 11 columns]

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

def get_lemmatization (x):
    sentence = x
    x_string=''
    sentence_words = word_tokenize(sentence)
    
    sentence_words = list(set(sentence_words))
    
    for word in sentence_words:
        x_string+=(wordnet_lemmatizer.lemmatize(word)+" ")
    return x_string.strip()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Wyatt\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df_sample['token']= [word_tokenize(entry) for entry in df_sample['text_en_only_rm_stopping']]

# %%
df_sample

# %%
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(df_sample['review'],df_sample['rating'],test_size=0.2)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(Train_X.tolist())
vectors.shape
# Out:
# (167783, 58475)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
pd.options.mode.chained_assignment = None    
vectors_test = vectorizer.transform(Test_X)

# %%
df_mnb=pd.DataFrame(columns=['MNB alpha value','Precision','Recall','F1 Score'])
df_mnb['MNB alpha value']=[0.001,0.01,0.1,1,10]

# %%
for i in df_mnb.index:
    mnb = MultinomialNB(alpha=df_mnb['MNB alpha value'][i])
    mnb.fit(vectors, Train_Y)
    pred = mnb.predict(vectors_test)
    df_mnb['Precision'][i]= metrics.precision_score(Test_Y, pred, average='weighted')
    df_mnb['Recall'][i]= metrics.recall_score(Test_Y, pred, average='weighted')
    df_mnb['F1 Score'][i]= metrics.f1_score(Test_Y, pred, average='weighted')
        

    
df_mnb.T
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                         0         1         2         3         4
# MNB alpha value     0.001      0.01       0.1         1        10
# Precision         0.50946  0.510557  0.511242  0.524666   0.43454
# Recall           0.510633  0.511944  0.510442  0.479617  0.424951
# F1 Score         0.505479  0.506409  0.503126  0.461275  0.382795

# %%
df_lr=pd.DataFrame(columns=['LR C value','Precision','Recall','F1 Score'])
df_lr['LR C value']=[0.001,0.01,0.1,1,10,100]

# %%
from sklearn.linear_model import LogisticRegression

for i in df_lr.index:
    clf =LogisticRegression(random_state=2020,multi_class = 'multinomial' , solver = 'newton-cg', C=df_lr['LR C value'][i]).fit(vectors, Train_Y)
    pred = clf.predict(vectors_test)
    df_lr['Precision'][i]= metrics.precision_score(Test_Y, pred, average='weighted')
    df_lr['Recall'][i]= metrics.recall_score(Test_Y, pred, average='weighted')
    df_lr['F1 Score'][i]= metrics.f1_score(Test_Y, pred, average='weighted')
    
df_lr.T
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                    0         1         2         3         4         5
# LR C value     0.001      0.01       0.1         1        10       100
# Precision    0.33979   0.49447  0.506006  0.518958  0.535992  0.533571
# Recall       0.37739  0.459901   0.49938  0.522362  0.539003  0.535617
# F1 Score    0.334237    0.4452  0.488989  0.516592  0.535702  0.533709

# %%
df_svm=pd.DataFrame(columns=['svm C value','Precision','Recall','F1 Score'])
df_svm['svm C value']=[0.001,0.01,0.1,1,10,100]

# %%
#svm
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(vectors,Train_Y)
 
predictions_SVM = SVM.predict(vectors_test)
 
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM,Test_Y )*100)

# %%
for i in df_svm.index:
    SVM =svm.SVC(C=df_svm['svm C value'][i], kernel='linear', degree=3, gamma='auto') 
    SVM.fit(vectors,Train_Y)
    pred = SVM.predict(vectors_test)
    
    df_svm['Precision'][i]= metrics.precision_score(Test_Y, pred, average='weighted')
    df_svm['Recall'][i]= metrics.recall_score(Test_Y, pred, average='weighted')
    df_svm['F1 Score'][i]= metrics.f1_score(Test_Y, pred, average='weighted')
    
df_svm.T
